# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DV0101EN/labs/Data_Files/Canada.xlsx"
df = pd.read_excel(url, sheet_name='Canada by Citizenship',skiprows=range(20), skipfooter=2)
df.tail()
# Out:
#            Type    Coverage          OdName  AREA AreaName  REG  \
# 190  Immigrants  Foreigners        Viet Nam   935     Asia  920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa  912
# 192  Immigrants  Foreigners           Yemen   935     Asia  922
# 193  Immigrants  Foreigners          Zambia   903   Africa  910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa  910
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 190  South-Eastern Asia  902  Developing regions  1191  ...  1816  1852  3153
# 191     Northern Africa  902  Developing regions     0  ...     0     0     1
# 192        Western Asia  902  Developing regions     1  ...   124   161   140
# 193      Eastern Africa  902  Developing regions    11  ...    56    91    77
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
#
#      2007  2008  2009  2010  2011  2012  2013
# 190  2574  1784  2171  1942  1723  1731  2112
# ...

# %%
# to remove select colums
df.drop(columns=['Type','Coverage','DEV','AREA','REG'],inplace=True)

# %%
df.rename(columns={'OdName':'Country','AreaName':'Continent'}, inplace=True)

# %%
df.set_index('Country',inplace=True)
# df.reset_index(inplace=True)

# %%
years = list(range(1980,2014))
years
# Out:
# [1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
df.loc['India',years].plot()
plt.title('India Immigration from 1980 to 2013')
plt.xlabel(years)
plt.ylabel('Immigration Count')
plt.show()

# %%
df.loc['China',years].plot(figsize=(10,5))
plt.title('China Immigration from 1980 to 2013')
plt.xlabel(years)
plt.ylabel('Immigration Count', size=20)
plt.show()

# %%
# transposing data
df.loc[['China','India'],years]
# Out:
#          1980  1981  1982  1983  1984  1985  1986   1987   1988   1989  ...  \
# Country                                                                 ...
# China    5123  6682  3308  1863  1527  1816  1960   2643   2758   4323  ...
# India    8880  8670  8147  7338  5704  4211  7150  10189  11522  10343  ...
#
#           2004   2005   2006   2007   2008   2009   2010   2011   2012   2013
# Country
# China    36619  42584  33518  27642  30037  29622  30391  28502  33024  34129
# India    28235  36210  33848  28742  28261  29456  34235  27509  30933  33087
#
# [2 rows x 34 columns]

# %%
df[df['Continent']== 'Asia'][years].sort_values(2013, ascending=False).head(10).T.plot(figsize=(14,6))
plt.xticks(size=12, rotation=30)
plt.yticks(size=12)
plt.show()

# %%
 # [[2011,2012,2013]].T.plot(kind='bar')
df
# Out:
#                Continent             RegName             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
df[years].sum().plot(kind='bar',figsize=(15,6))
# Out:
# <AxesSubplot:>

# %%
years = list(range(2010, 2011))
df[df["Continent"] == "Europe"][years].sort_values (2010, ascending=False).head(10).plot(kind='bar')
plt.title('Europe (Top 10 Countries) Immigration counts for the year 2010', size = 15)
plt.xlabel('Countries', size = 12)
plt.ylabel('Immigration Count', size = 12)
plt.xticks(size=10, rotation=-90)
plt.yticks(size=8)
plt.show()

# %%
df ['total'] = df.sum(axis=1)
# Out:
# C:\Users\ashut\AppData\Local\Temp\ipykernel_1728\604929604.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df ['total'] = df.sum(axis=1)

# %%
df
# Out:
#                Continent             RegName             DevName  1980  1981  \
# Country
# Afghanistan         Asia       Southern Asia  Developing regions    16    39
# Albania           Europe     Southern Europe   Developed regions     1     0
# Algeria           Africa     Northern Africa  Developing regions    80    67
# American Samoa   Oceania           Polynesia  Developing regions     0     1
# Andorra           Europe     Southern Europe   Developed regions     0     0
# ...                  ...                 ...                 ...   ...   ...
# Viet Nam            Asia  South-Eastern Asia  Developing regions  1191  1829
# Western Sahara    Africa     Northern Africa  Developing regions     0     0
# Yemen               Asia        Western Asia  Developing regions     1     2
# Zambia            Africa      Eastern Africa  Developing regions    11    17
# Zimbabwe          Africa      Eastern Africa  Developing regions    72   114
#
# ...

# %%
continent =df.groupby('Continent').sum()['total']

# %%
continent.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='total'>

# %%
continent.plot(kind='pie', autopct="%1.1f%%", pctdistance=1.2, labels=None, figsize= (15,7))
plt.title('Total Continent contribution to immigration')
plt.show()
